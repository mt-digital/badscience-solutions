# %%
from vis import fpr_allpi, policies_timeseries
from experiment_data import ExperimentData

# %%
ed = ExperimentData('finaldraft-scimod.hdf')
policies_timeseries(ed, 
    save_path='/Users/mt/workspace/papers/scimod/Figures/meas_v_time.pdf')

# %% [markdown]
# ## Scratch

# %%
from experiment_data import ExperimentData
ed = ExperimentData('Fig3Demo.hdf')

# %%
d = ed.hdf
print(list(d.keys()))
print(list(d['PUBLICATIONS'].keys()))
# Out:
# ['FPR', 'PUBLICATIONS', 'RANDOM']
# ['10']

# %%
ed.pubneg_rates
# Out:
# ['0.10', '0.50', '0.90']

# %%
policy = 'RANDOM'
G = '10'
npr = '0.50'
agentFPRs = ed[policy, '10', npr, '0.00']['agentFPRs'][:]
agentFPRs.shape
# Out:
# (1, 100, 100)

# %%
from itertools import repeat

# %%
nSteps = 100
N = 100
x = np.array([j for i in range(nSteps)
                for j in [i]*N 
             ])
y = agentFPRs.flatten()
plt.plot(x, y, '.')

# %%
fpr_allpi(ed)

# %%
# edfpdr.hdf.close()
# ed.hdf.close()
# edfpdr = ExperimentData('Fig5Demo.hdf')

ed = ExperimentData('fpr-over-npr_fpdr-allagents.hdf')
print(ed.award_amounts)
print(ed.fpdrs)
print(ed.pubneg_rates)
# Out:
# ['10', '35', '60', '85']
# ['0.10', '0.50', '0.90']
# ['0.00', '0.10', '0.50', '0.90']

# %%
fpr_allpi(ed, G=10, param='FPDR', figsize=(8, 3), save_path='/Users/mt/workspace/papers/scimod/Figures/fpr-over-fpdr-allagents.pdf')

# %%
# ed = ExperimentData('Fig3Demo.hdf')
# print(ed.fpdrs)
# print(ed.pubneg_rates)
fpr_allpi(ed, G='10', param='NPR', save_path='/Users/mt/workspace/papers/scimod/Figures/fpr-over-npr-allagents.pdf', figsize=(8, 3))

# %%
ed.award_amounts
# Out:
# ['10', '35', '60', '85']

# %%
ed.fpdrs
# Out:
# ['0.10', '0.50', '0.90']

# %%
ed.pubneg_rates
# Out:
# ['0.00', '0.10', '0.50', '0.90']

# %%
ed.hdf['/RANDOM/60/0.90'].keys()
# Out:
# KeysView(<HDF5 group "/RANDOM/60/0.90" (1 members)>)
